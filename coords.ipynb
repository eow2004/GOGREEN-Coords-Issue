# %% [markdown]
# ```.
# name: gogreenmsr
# channels:
#   - defaults
#   - conda-forge
# dependencies:
#   - _libgcc_mutex=0.1=main
#   - _openmp_mutex=5.1=1_gnu
#   - asttokens=3.0.0=pyhd8ed1ab_1
#   - bzip2=1.0.8=h5eee18b_6
#   - ca-certificates=2025.8.3=hbd8a1cb_0
#   - comm=0.2.3=pyhe01879c_0
#   - debugpy=1.8.11=py39h6a678d5_0
#   - decorator=5.2.1=pyhd8ed1ab_0
#   - exceptiongroup=1.3.0=pyhd8ed1ab_0
#   - executing=2.2.0=pyhd8ed1ab_0
#   - expat=2.7.1=h6a678d5_0
#   - importlib-metadata=8.7.0=pyhe01879c_1
#   - ipykernel=6.30.1=pyh82676e8_0
#   - ipython=8.18.1=pyh707e725_3
#   - jedi=0.19.2=pyhd8ed1ab_1
#   - jupyter_client=8.6.3=pyhd8ed1ab_1
#   - jupyter_core=5.8.1=pyh31011fe_0
#   - ld_impl_linux-64=2.40=h12ee557_0
#   - libffi=3.4.4=h6a678d5_1
#   - libgcc-ng=11.2.0=h1234567_1
#   - libgomp=11.2.0=h1234567_1
#   - libsodium=1.0.18=h36c2ea0_1
#   - libstdcxx-ng=11.2.0=h1234567_1
#   - libxcb=1.17.0=h9b100fa_0
#   - matplotlib-inline=0.1.7=pyhd8ed1ab_1
#   - ncurses=6.5=h7934f7d_0
#   - nest-asyncio=1.6.0=pyhd8ed1ab_1
#   - openssl=3.0.17=h5eee18b_0
#   - packaging=25.0=pyh29332c3_1
#   - parso=0.8.4=pyhd8ed1ab_1
#   - pexpect=4.9.0=pyhd8ed1ab_1
#   - pickleshare=0.7.5=pyhd8ed1ab_1004
#   - pip=25.1=pyhc872135_2
#   - platformdirs=4.3.8=pyhe01879c_0
#   - prompt-toolkit=3.0.51=pyha770c72_0
#   - psutil=5.9.1=py39hb9d737c_0
#   - pthread-stubs=0.3=h0ce48e5_1
#   - ptyprocess=0.7.0=pyhd8ed1ab_1
#   - pure_eval=0.2.3=pyhd8ed1ab_1
#   - pygments=2.19.2=pyhd8ed1ab_0
#   - python=3.9.23=he99959a_0
#   - python-dateutil=2.9.0.post0=pyhe01879c_2
#   - python_abi=3.9=2_cp39
#   - pyzmq=26.2.0=py39h6a678d5_0
#   - readline=8.3=hc2a1206_0
#   - setuptools=78.1.1=py39h06a4308_0
#   - six=1.17.0=pyhe01879c_1
#   - sqlite=3.50.2=hb25bd0a_1
#   - stack_data=0.6.3=pyhd8ed1ab_1
#   - tk=8.6.15=h54e0aa7_0
#   - tornado=6.5.1=py39h5eee18b_0
#   - traitlets=5.14.3=pyhd8ed1ab_1
#   - typing_extensions=4.14.1=pyhe01879c_0
#   - wcwidth=0.2.13=pyhd8ed1ab_1
#   - wheel=0.45.1=py39h06a4308_0
#   - xorg-libx11=1.8.12=h9b100fa_1
#   - xorg-libxau=1.0.12=h9b100fa_0
#   - xorg-libxdmcp=1.1.5=h9b100fa_0
#   - xorg-xorgproto=2024.1=h5eee18b_1
#   - xz=5.6.4=h5eee18b_1
#   - zeromq=4.3.5=h6a678d5_0
#   - zipp=3.23.0=pyhd8ed1ab_0
#   - zlib=1.2.13=h5eee18b_1
#   - pip:
#       - astropy==6.0.1
#       - astropy-iers-data==0.2025.8.18.0.40.14
#       - contourpy==1.3.0
#       - cycler==0.12.1
#       - fonttools==4.59.1
#       - importlib-resources==6.5.2
#       - kiwisolver==1.4.7
#       - matplotlib==3.9.4
#       - numpy==1.26.4
#       - pandas==2.3.2
#       - pillow==11.3.0
#       - pyerfa==2.0.1.5
#       - pyparsing==3.2.3
#       - pytz==2025.2
#       - pyyaml==6.0.2
#       - scipy==1.13.1
#       - tzdata==2025.2

# %% [markdown]
# Here is my environment.yml file for the Python kernel I am running on this project. A lot of these dependancies are probably holdovers from other kernels or extentions on my IDE, but I figured I'd put the whole thing down for completeness.

# %% [markdown]
# ## Working Directories and File Information

# %% [markdown]
# ### GOGREEN Directory

# %% [markdown]
# ```.
# .
# ├── DR2
# │   ├── CATS
# │   │   ├── Clusters.fits
# │   │   ├── Photo.fits
# │   │   ├── Redshift_catalogue.fits
# │   │   ├── table3_cosmos.csv
# │   │   ├── table3_gclass.csv
# │   │   ├── table3_gogreen.csv
# │   │   └── table3_sxdf.csv
# │   ├── GOGREEN_and_GCLASS_Data_Release_DR2.pdf
# │   ├── PHOTOMETRY
# │   │   ├── BESTFIT_SEDs
# │   │   │   ├── SpARCS-0034
# │   │   │   │   ├── SED_263.fit
# │   │   │   │   ├── cont.
# │   │   │   │   └── SED_949.fit
# │   │   │   ├── SpARCS-0035
# │   │   │   │   ├── SpARCS-0035_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-0035_indivz.tar.gz
# │   │   │   │   └── SpARCS-0035_specz.tarz
# │   │   │   ├── SpARCS-0036
# │   │   │   │   ├── SED_1002.fit
# │   │   │   │   ├── cont.
# │   │   │   │   └── SED_992.fit
# │   │   │   ├── SpARCS-0215
# │   │   │   │   ├── SED_1018.fit
# │   │   │   │   ├── cont.
# │   │   │   │   └── SED_985.fit
# │   │   │   ├── SpARCS-0219
# │   │   │   │   ├── SpARCS-0219_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-0219_indivz.tar.gz
# │   │   │   │   └── SpARCS-0219_specz.tarz
# │   │   │   ├── SpARCS-0335
# │   │   │   │   ├── SpARCS-0335_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-0335_indivz.tar.gz
# │   │   │   │   └── SpARCS-0335_specz.tarz
# │   │   │   ├── SpARCS-1034
# │   │   │   │   ├── SpARCS-1034_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-1034_indivz.tar.gz
# │   │   │   │   └── SpARCS-1034_specz.tarz
# │   │   │   ├── SpARCS-1047
# │   │   │   │   ├── SED_1855.fit
# │   │   │   │   ├── cont.
# │   │   │   │   └── SED_5585.fit
# │   │   │   ├── SpARCS-1051
# │   │   │   │   ├── SpARCS-1051_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-1051_indivz.tar.gz
# │   │   │   │   └── SpARCS-1051_specz.tarz
# │   │   │   ├── SpARCS-1613
# │   │   │   │   ├── SED_2005.fit
# │   │   │   │   ├── cont.
# │   │   │   │   └── SED_5273.fit
# │   │   │   ├── SpARCS-1616
# │   │   │   │   ├── SpARCS-1616_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-1616_indivz.tar.gz
# │   │   │   │   └── SpARCS-1616_specz.tarz
# │   │   │   ├── SpARCS-1634
# │   │   │   │   ├── SpARCS-1634_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-1634_indivz.tar.gz
# │   │   │   │   └── SpARCS-1634_specz.tarz
# │   │   │   ├── SpARCS-1638
# │   │   │   │   ├── SpARCS-1638_clusterz.tar.gz
# │   │   │   │   ├── SpARCS-1638_indivz.tar.gz
# │   │   │   │   └── SpARCS-1638_specz.tarz
# │   │   │   ├── SPTCL-0205
# │   │   │   │   ├── SPTCL-0205_clusterz.tar.gz
# │   │   │   │   ├── SPTCL-0205_indivz.tar.gz
# │   │   │   │   └── SPTCL-0205_specz.tarz
# │   │   │   ├── SPTCL-0546
# │   │   │   │   ├── SPTCL-0546_clusterz.tar.gz
# │   │   │   │   ├── SPTCL-0546_indivz.tar.gz
# │   │   │   │   └── SPTCL-0546_specz.tarz
# │   │   │   └── SPTCL-2106
# │   │   │       ├── SPTCL-2106_clusterz.tar.gz
# │   │   │       ├── SPTCL-2106_indivz.tar.gz
# │   │   │       └── SPTCL-2106_specz.tarz
# │   │   ├── COLORIMS
# │   │   │   ├── SpARCS-0034_giK_big.jpg
# │   │   │   ├── SpARCS-0034_giK.jpg
# │   │   │   ├── SpARCS-0034_giK_mark.jpg
# │   │   │   ├── SpARCS-0035.jpg
# │   │   │   ├── SpARCS-0035_label.jpg
# │   │   │   ├── SpARCS-0035_mark.jpg
# │   │   │   ├── SpARCS-0035_mark_label.jpg
# │   │   │   ├── SpARCS-0036_giK_big.jpg
# │   │   │   ├── SpARCS-0036_giK.jpg
# │   │   │   ├── SpARCS-0036_giK_mark.jpg
# │   │   │   ├── SpARCS-0215_giK_big.jpg
# │   │   │   ├── SpARCS-0215_giK.jpg
# │   │   │   ├── SpARCS-0215_giK_mark.jpg
# │   │   │   ├── SpARCS-0219.jpg
# │   │   │   ├── SpARCS-0219_label.jpg
# │   │   │   ├── SpARCS-0219_mark.jpg
# │   │   │   ├── SpARCS-0219_mark_label.jpg
# │   │   │   ├── SpARCS-0335.jpg
# │   │   │   ├── SpARCS-0335_label.jpg
# │   │   │   ├── SpARCS-0335_mark.jpg
# │   │   │   ├── SpARCS-0335_mark_label.jpg
# │   │   │   ├── SpARCS-1034.jpg
# │   │   │   ├── SpARCS-1034_label.jpg
# │   │   │   ├── SpARCS-1034_mark.jpg
# │   │   │   ├── SpARCS-1034_mark_label.jpg
# │   │   │   ├── SpARCS-1047_giK_big.jpg
# │   │   │   ├── SpARCS-1047_giK.jpg
# │   │   │   ├── SpARCS-1047_giK_mark.jpg
# │   │   │   ├── SpARCS-1051.jpg
# │   │   │   ├── SpARCS-1051_label.jpg
# │   │   │   ├── SpARCS-1051_mark.jpg
# │   │   │   ├── SpARCS-1051_mark_label.jpg
# │   │   │   ├── SpARCS-1613_giK_big.jpg
# │   │   │   ├── SpARCS-1613_giK.jpg
# │   │   │   ├── SpARCS-1613_giK_mark.jpg
# │   │   │   ├── SpARCS-1616.jpg
# │   │   │   ├── SpARCS-1616_label.jpg
# │   │   │   ├── SpARCS-1616_mark.jpg
# │   │   │   ├── SpARCS-1616_mark_label.jpg
# │   │   │   ├── SpARCS-1634.jpg
# │   │   │   ├── SpARCS-1634_label.jpg
# │   │   │   ├── SpARCS-1634_mark.jpg
# │   │   │   ├── SpARCS-1634_mark_label.jpg
# │   │   │   ├── SpARCS-1638.jpg
# │   │   │   ├── SpARCS-1638_label.jpg
# │   │   │   ├── SpARCS-1638_mark.jpg
# │   │   │   ├── SpARCS-1638_mark_label.jpg
# │   │   │   ├── SPTCL-0205.jpg
# │   │   │   ├── SPTCL-0205_label.jpg
# │   │   │   ├── SPTCL-0205_mark.jpg
# │   │   │   ├── SPTCL-0205_mark_label.jpg
# │   │   │   ├── SPTCL-0546.jpg
# │   │   │   ├── SPTCL-0546_label.jpg
# │   │   │   ├── SPTCL-0546_mark.jpg
# │   │   │   ├── SPTCL-0546_mark_label.jpg
# │   │   │   ├── SPTCL-2106.jpg
# │   │   │   ├── SPTCL-2106_label.jpg
# │   │   │   ├── SPTCL-2106_mark.jpg
# │   │   │   └── SPTCL-2106_mark_label.jpg
# │   │   ├── COSMOS
# │   │   │   ├── UVISTA_final_colors_sfrs_v4.1.dat
# │   │   │   ├── UVISTA_final_v4.1_t1.fits
# │   │   │   └── UVISTA_final_v4.1_zout.fits
# │   │   ├── PHOTOM_CATS
# │   │   │   ├── config_phot.sex
# │   │   │   ├── SpARCS-0034_v2.0.cat
# │   │   │   ├── SpARCS-0035_totalall_HAWKIKs.cat
# │   │   │   ├── SpARCS-0035_totalall_HAWKIKs_starflag.cat
# │   │   │   ├── SpARCS-0036_v2.0.cat
# │   │   │   ├── SpARCS-0215_v2.0.cat
# │   │   │   ├── SpARCS-0219_totalall_FOURSTARKs.cat
# │   │   │   ├── SpARCS-0219_totalall_FOURSTARKs_starflag.cat
# │   │   │   ├── SpARCS-0335_totalall_FOURSTARKs.cat
# │   │   │   ├── SpARCS-0335_totalall_FOURSTARKs_starflag.cat
# │   │   │   ├── SpARCS-1033_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1033_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SpARCS-1034_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1034_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SpARCS-1047_v2.0.cat
# │   │   │   ├── SpARCS-1051_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1051_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SpARCS-1613_v2.0.cat
# │   │   │   ├── SpARCS-1616_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1616_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SpARCS-1634_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1634_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SpARCS-1638_totalall_WIRCamK.cat
# │   │   │   ├── SpARCS-1638_totalall_WIRCamK_starflag.cat
# │   │   │   ├── SPTCL-0205_totalall_FOURSTARKs.cat
# │   │   │   ├── SPTCL-0205_totalall_FOURSTARKs_starflag.cat
# │   │   │   ├── SPTCL-0546_totalall_FOURSTARKs.cat
# │   │   │   ├── SPTCL-0546_totalall_FOURSTARKs_starflag.cat
# │   │   │   ├── SPTCL-2106_totalall_HAWKIKs.cat
# │   │   │   └── SPTCL-2106_totalall_HAWKIKs_starflag.cat
# │   │   ├── PHOTOZ_CATS
# │   │   │   ├── Pofz
# │   │   │   │   ├── SpARCS-0035_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-0219_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-0335_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-1034_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-1051_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-1616_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-1634_totalall_Ks.pz
# │   │   │   │   ├── SpARCS-1638_totalall_Ks.pz
# │   │   │   │   ├── SPTCL-0205_totalall_Ks.pz
# │   │   │   │   ├── SPTCL-0546_totalall_Ks.pz
# │   │   │   │   └── SPTCL-2106_totalall_Ks.pz
# │   │   │   ├── SpARCS-0034_v2.0.zout
# │   │   │   ├── SpARCS-0035_totalall_Ks.zout
# │   │   │   ├── SpARCS-0035_zphot.dat
# │   │   │   ├── SpARCS-0036_v2.0.zout
# │   │   │   ├── SpARCS-0215_v2.0.zout
# │   │   │   ├── SpARCS-0219_totalall_Ks.zout
# │   │   │   ├── SpARCS-0219_zphot.dat
# │   │   │   ├── SpARCS-0335_totalall_Ks.zout
# │   │   │   ├── SpARCS-0335_zphot.dat
# │   │   │   ├── SpARCS-1033_totalall_Ks.zout
# │   │   │   ├── SpARCS-1033_zphot.dat
# │   │   │   ├── SpARCS-1034_totalall_Ks.zout
# │   │   │   ├── SpARCS-1034_zphot.dat
# │   │   │   ├── SpARCS-1047_v2.0.zout
# │   │   │   ├── SpARCS-1051_totalall_Ks.zout
# │   │   │   ├── SpARCS-1051_zphot.dat
# │   │   │   ├── SpARCS-1613_v2.0.zout
# │   │   │   ├── SpARCS-1616_totalall_Ks.zout
# │   │   │   ├── SpARCS-1616_zphot.dat
# │   │   │   ├── SpARCS-1634_totalall_Ks.zout
# │   │   │   ├── SpARCS-1634_zphot.dat
# │   │   │   ├── SpARCS-1638_totalall_Ks.zout
# │   │   │   ├── SpARCS-1638_zphot.dat
# │   │   │   ├── SPTCL-0205_totalall_Ks.zout
# │   │   │   ├── SPTCL-0205_zphot.dat
# │   │   │   ├── SPTCL-0546_totalall_Ks.zout
# │   │   │   ├── SPTCL-0546_zphot.dat
# │   │   │   ├── SPTCL-2106_totalall_Ks.zout
# │   │   │   └── SPTCL-2106_zphot.dat
# │   │   ├── README
# │   │   ├── README.gclass
# │   │   ├── RESTFRAME_COLOURS
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0035.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0035_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0219.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0219_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0335.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-0335_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1033.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1033_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1034.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1034_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1051.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1051_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1616.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1616_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1634.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1634_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1638.cat
# │   │   │   ├── RESTFRAME_MASTER_SpARCS-1638_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-0205.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-0205_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-0546.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-0546_indivredshifts.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-2106.cat
# │   │   │   ├── RESTFRAME_MASTER_SPTCL-2106_indivredshifts.cat
# │   │   │   ├── SpARCS-0034_UV_v2.0.rf
# │   │   │   ├── SpARCS-0034_VJ_v2.0.rf
# │   │   │   ├── SpARCS-0036_UV_v2.0.rf
# │   │   │   ├── SpARCS-0036_VJ_v2.0.rf
# │   │   │   ├── SpARCS-0215_UV_v2.0.rf
# │   │   │   ├── SpARCS-0215_VJ_v2.0.rf
# │   │   │   ├── SpARCS-1047_UV_v2.0.rf
# │   │   │   ├── SpARCS-1047_VJ_v2.0.rf
# │   │   │   ├── SpARCS-1613_UV_v2.0.rf
# │   │   │   ├── SpARCS-1613_VJ_v2.0.rf
# │   │   │   └── UVJcorrections.dat
# │   │   ├── SPECZ_MATCHED
# │   │   │   ├── compilation_SpARCS-0034.dat
# │   │   │   ├── compilation_SpARCS-0035.dat
# │   │   │   ├── compilation_SpARCS-0036.dat
# │   │   │   ├── compilation_SpARCS-0215.dat
# │   │   │   ├── compilation_SpARCS-0219.dat
# │   │   │   ├── compilation_SpARCS-0335.dat
# │   │   │   ├── compilation_SpARCS-1033.dat
# │   │   │   ├── compilation_SpARCS-1034.dat
# │   │   │   ├── compilation_SpARCS-1047.dat
# │   │   │   ├── compilation_SpARCS-1051.dat
# │   │   │   ├── compilation_SpARCS-1613.dat
# │   │   │   ├── compilation_SpARCS-1616.dat
# │   │   │   ├── compilation_SpARCS-1634.dat
# │   │   │   ├── compilation_SpARCS-1638.dat
# │   │   │   ├── compilation_SPTCL-0205.dat
# │   │   │   ├── compilation_SPTCL-0546.dat
# │   │   │   └── compilation_SPTCL-2106.dat
# │   │   ├── STELMASS_CATS
# │   │   │   ├── SpARCS-0034_v2.0.fout
# │   │   │   ├── SpARCS-0035_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-0035_totalall_Ks.fout
# │   │   │   ├── SpARCS-0036_v2.0.fout
# │   │   │   ├── SpARCS-0215_v2.0.fout
# │   │   │   ├── SpARCS-0219_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-0219_totalall_Ks.fout
# │   │   │   ├── SpARCS-0335_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-0335_totalall_Ks.fout
# │   │   │   ├── SpARCS-1033_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1033_totalall_Ks.fout
# │   │   │   ├── SpARCS-1034_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1034_totalall_Ks.fout
# │   │   │   ├── SpARCS-1047_v2.0.fout
# │   │   │   ├── SpARCS-1051_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1051_totalall_Ks.fout
# │   │   │   ├── SpARCS-1613_v2.0.fout
# │   │   │   ├── SpARCS-1616_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1616_totalall_Ks.fout
# │   │   │   ├── SpARCS-1634_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1634_totalall_Ks.fout
# │   │   │   ├── SpARCS-1638_totalall_Ks_fixz.fout
# │   │   │   ├── SpARCS-1638_totalall_Ks.fout
# │   │   │   ├── SPTCL-0205_totalall_Ks_fixz.fout
# │   │   │   ├── SPTCL-0205_totalall_Ks.fout
# │   │   │   ├── SPTCL-0546_totalall_Ks_fixz.fout
# │   │   │   ├── SPTCL-0546_totalall_Ks.fout
# │   │   │   ├── SPTCL-2106_totalall_Ks_fixz.fout
# │   │   │   └── SPTCL-2106_totalall_Ks.fout
# │   │   └── SXDF
# │   │       ├── README
# │   │       ├── SPLASH_SXDF_Mehta+_v1.6_GOGREEN_FOV_rfcolours.csv
# │   │       └── SPLASH_SXDF_Mehta+_v1.6_GOGREEN_FOV_rfcolours_README
# │   ├── proposal_plots.ipynb
# │   ├── README
# │   ├── Scripts
# │   │   ├── Checkphotozp.ipynb
# │   │   ├── DR2_build_Table3.ipynb
# │   │   ├── DR2_Notebook.ipynb
# │   │   └── DR2_stats_and_checks.ipynb
# │   ├── SPECTROSCOPY
# │   │   ├── OneD
# │   │   │   ├── COSMOS-125_final.fits
# │   │   │   ├── COSMOS-221_final.fits
# │   │   │   ├── COSMOS-28_final.fits
# │   │   │   ├── COSMOS-63_final.fits
# │   │   │   ├── README
# │   │   │   ├── SpARCS0034_final.fits
# │   │   │   ├── SpARCS0035_final.fits
# │   │   │   ├── SpARCS0036_final.fits
# │   │   │   ├── SpARCS0215_final.fits
# │   │   │   ├── SpARCS0219_final.fits
# │   │   │   ├── SpARCS0335_final.fits
# │   │   │   ├── SpARCS1033_final.fits
# │   │   │   ├── SpARCS1034_final.fits
# │   │   │   ├── SpARCS1047_final.fits
# │   │   │   ├── SpARCS1051_final.fits
# │   │   │   ├── SpARCS1613_final.fits
# │   │   │   ├── SpARCS1616_final.fits
# │   │   │   ├── SpARCS1634_final.fits
# │   │   │   ├── SpARCS1638_final.fits
# │   │   │   ├── SPT0205_final.fits
# │   │   │   ├── SPT0546_final.fits
# │   │   │   ├── SPT2106_final.fits
# │   │   │   ├── SXDF49_final.fits
# │   │   │   ├── SXDF64_final.fits
# │   │   │   └── SXDF76_final.fits
# │   │   └── TwoD
# │   │       ├── COSMOS-125_twod.fits.gz
# │   │       ├── COSMOS-221_twod.fits.gz
# │   │       ├── COSMOS-28_twod.fits.gz
# │   │       ├── COSMOS-63_twod.fits.gz
# │   │       ├── README
# │   │       ├── SpARCS0035_twod.fits.gz
# │   │       ├── SpARCS0219_twod.fits.gz
# │   │       ├── SpARCS0335_twod.fits.gz
# │   │       ├── SpARCS1033_twod.fits.gz
# │   │       ├── SpARCS1034_twod.fits.gz
# │   │       ├── SpARCS1051_twod.fits.gz
# │   │       ├── SpARCS1616_twod.fits.gz
# │   │       ├── SpARCS1634_twod.fits.gz
# │   │       ├── SpARCS1638_twod.fits.gz
# │   │       ├── SPT0205_twod.fits.gz
# │   │       ├── SPT0546_twod.fits.gz
# │   │       ├── SPT2106_twod.fits.gz
# │   │       ├── SXDF49_twod.fits.gz
# │   │       ├── SXDF64_twod.fits.gz
# │   │       └── SXDF76_twod.fits.gz
# │   ├── STELLPOPS_V2
# │   │   ├── photometry_stellpops.fits
# │   │   ├── README.txt
# │   │   └── redshifts_stellpops.fits
# │   └── STRUCTURAL_PARA_v1.1_CATONLY
# │       ├── GALFIT_ORG_CATS
# │       │   ├── gal_spj0035_orgcat.fits
# │       │   ├── gal_spj0219_orgcat.fits
# │       │   ├── gal_spj0335_orgcat.fits
# │       │   ├── gal_spj1034_orgcat.fits
# │       │   ├── gal_spj1051_orgcat.fits
# │       │   ├── gal_spj1616_orgcat.fits
# │       │   ├── gal_spj1634_orgcat.fits
# │       │   ├── gal_spj1638_orgcat.fits
# │       │   ├── gal_spt0205_orgcat.fits
# │       │   ├── gal_spt0546_orgcat.fits
# │       │   └── gal_spt2106_orgcat.fits
# │       ├── README
# │       └── STRUCTCAT_MATCHED
# │           ├── structcat_photmatch_spj0035.csv
# │           ├── structcat_photmatch_spj0035.dat
# │           ├── structcat_photmatch_spj0219.csv
# │           ├── structcat_photmatch_spj0219.dat
# │           ├── structcat_photmatch_spj0335.csv
# │           ├── structcat_photmatch_spj0335.dat
# │           ├── structcat_photmatch_spj1034.csv
# │           ├── structcat_photmatch_spj1034.dat
# │           ├── structcat_photmatch_spj1051.csv
# │           ├── structcat_photmatch_spj1051.dat
# │           ├── structcat_photmatch_spj1616.csv
# │           ├── structcat_photmatch_spj1616.dat
# │           ├── structcat_photmatch_spj1634.csv
# │           ├── structcat_photmatch_spj1634.dat
# │           ├── structcat_photmatch_spj1638.csv
# │           ├── structcat_photmatch_spj1638.dat
# │           ├── structcat_photmatch_spt0205.csv
# │           ├── structcat_photmatch_spt0205.dat
# │           ├── structcat_photmatch_spt0546.csv
# │           ├── structcat_photmatch_spt0546.dat
# │           ├── structcat_photmatch_spt2106.csv
# │           └── structcat_photmatch_spt2106.dat
# ├── GOGREEN-Research
# │   ├── Code
# │   │   ├── GOGREEN.py
# │   │   └── README
# │   ├── Notebooks
# │   │   ├── KFlagChecks.ipynb
# │   │   ├── McNab-Reproduction.ipynb
# │   │   ├── MembershipDefinitions.ipynb
# │   │   ├── NotebookCompendium.txt
# │   │   ├── proposal_plots_updated.ipynb
# │   │   ├── testOutput.txt
# │   │   ├── TestPlots.ipynb
# │   │   ├── TransitionTrends.ipynb
# │   │   ├── truth.txt
# │   │   └── Tutorial.ipynb
# │   ├── proposal_plots.ipynb
# │   ├── proposal_plots_updated.ipynb
# │   ├── README.md
# │   └── Resources
# │       ├── DR1_Notebook.ipynb
# │       ├── StandardCriteria.docx
# │       └── testAnalysis.xlsx
# ├── Tutorial copy.ipynb
# └── Tutorial.ipynb
#
# 43 directories, 991 files

# %% [markdown]
# The DR2 folder contains all of the files from GOGREEN Data Release 2. The GOGREEN-Research folder, located at the end, contains the code and methods used in my research, built mainly by Freeman Spray. His full repository that I built off of is located at https://github.com/FreemanSpray/GOGREEN-Research. The main work is following the Tutorial.ipynb and GOGREEN.py files. No issues come up when doing the work using those programs. I will include relevant handling code from them when needed and will caption appropriately.

# %% [markdown]
# ### Fits Directory

# %% [markdown]
# ```.
# ├── gogreenfits
# │   ├── spj0035
# │   │   └── OBJFITS_spj0035
# │   │       ├── galb1_1000_v_gf.fits
# │   │       ├── galb1_1002_v_gf.fits
# │   │       ├── cont.
# │   ├── spj0219
# │   │   └── OBJFITS_spj0219
# │   │       ├── galb1_1000_v_gf.fits
# │   │       ├── galb1_1001_v_gf.fits
# │   │       ├── cont.
# │   ├── spj0335
# │   │   └── OBJFITS_spj0335
# │   │       ├── galb1_1012_v_gf.fits
# │   │       ├── galb1_1015_v_gf.fits
# │   │       ├── cont.
# │   ├── spj1034
# │   │   └── OBJFITS_spj1034
# │   │       ├── galb1_1002_v_gf.fits
# │   │       ├── galb1_1003_v_gf.fits
# │   │       ├── cont.
# │   ├── spj1051
# │   │   └── OBJFITS_spj1051
# │   │       ├── galb1_1003_v_gf.fits
# │   │       ├── galb1_1005_v_gf.fits
# │   │       ├── cont.
# │   ├── spj1616
# │   │   └── OBJFITS_spj1616
# │   │       ├── galb1_1001_v_gf.fits
# │   │       ├── galb1_1002_v_gf.fits
# │   │       ├── cont.
# │   ├── spj1634
# │   │   └── OBJFITS_spj1634
# │   │       ├── galb1_1006_v_gf.fits
# │   │       ├── galb1_1007_v_gf.fits
# │   │       ├── cont.
# │   ├── spj1638
# │   │   └── OBJFITS_spj1638
# │   │       ├── galb1_1004_v_gf.fits
# │   │       ├── galb1_1010_v_gf.fits
# │   │       ├── cont.
# │   ├── spt0205
# │   │   └── OBJFITS_spt0205
# │   │       ├── galb1_1001_v_gf.fits
# │   │       ├── galb1_1003_v_gf.fits
# │   │       ├── cont.
# │   ├── spt0546
# │   │   └── OBJFITS_spt0546
# │   │       ├── galb1_1002_v_gf.fits
# │   │       ├── galb1_1004_v_gf.fits
# │   │       ├── cont.
# │   └── spt2106
# │       └── OBJFITS_spt2106
# │           ├── galb1_1000_v_gf.fits
# │           ├── galb1_1002_v_gf.fits
# │           ├── cont.
# ├── results.csv
# └── sort4.py
#
# 24 directories, 14343 files

# %% [markdown]
# This folder contains the multi-extention fits files which contain the original modeling cutouts and results. The extentions of the multi-extention fits files are:\
# Ext 0: INPUT  Ext 1: MODEL  Ext 2: RESIDUAL, etc. I only use those 3. They have headers containing good WCS data.
#
# The folders divide by cluster, and each cluster has data stored in the GOGREEN directory at:\
# `DR2/STRUCTURAL_PARA_v1.1_CATONLY/GALFIT_ORG_CATS/gal_{cluster}_orgcat.fits`\
# which is a .fits table with the following columns of data:\
# \
# GALAPAGOS_VERSION, **GALA_ID**, **X_IMAGE**, **Y_IMAGE**, **ALPHA_J2000**, **DELTA_J2000**, MAG_AUTO, MAGERR_AUTO, CLASS_STAR, SKY_GALA_BAND, SKY_SIG_BAND, SKY_RAD_BAND, FLAG_GALFIT, NGOOD_GALFIT_BAND, NMASK_GALFIT_BAND, NEIGH_GALFIT, CHISQ_GALFIT, NFREE_GALFIT, NFIX_GALFIT, NDOF_GALFIT, CHI2NU_GALFIT, SKY_GALFIT_BAND, X_GALFIT_BAND, XERR_GALFIT_BAND, Y_GALFIT_BAND, YERR_GALFIT_BAND, MAG_GALFIT_BAND, MAGERR_GALFIT_BAND, RE_GALFIT_BAND, REERR_GALFIT_BAND, N_GALFIT_BAND, NERR_GALFIT_BAND, Q_GALFIT_BAND, QERR_GALFIT_BAND, PA_GALFIT_BAND, PAERR_GALFIT_BAND\
# \
# and\
# \
# `DR2/STRUCTURAL_PARA_v1.1_CATONLY/STRUCTCAT_MATCHED/structcat_photmatch_{cluster}.dat` which is a raw text file with the following columns of data:\
# **PHOTCATID**, HSTFOV_flag, Fit_flag, mag, mag_err, re, re_err, n, n_err, q, q_err, pa, pa_err, dist, **hst_id**, chi2nu, S/N

# %% [markdown]
# ## Merging in the GOGREEN Class

# %% [markdown]
# The work I do using GOGREEN works primarily through the class created by the GOGREEN.py file, detailed in the Tutorial.ipynb in the repository by Freeman. It requires lots of data from multiple sources in the second data release, and the initialization of the class handles the merging of these file sources. I will document the flow of data through here, with code snippits from GOGREEN.py.

# %%
def init(self, priorCatalog:pd.DataFrame=None, usePhotMembership:bool=True):
    """
    init Helper method for initializing catalogs

    :param priorCatalog:   If we already have our catalog up to date and recompiling to update something else, it is passed in as this parameter
                            Default: None
    :param usePhotMembership: flag indicating whether photometric members should be included in the membership definition
                            Default: True
    """ 
    # Build path string to the cluster catalog
    clusterCatPath = self._path + 'DR2/CATS/Clusters.fits'
    # Generate a DataFrame of the catalog data
    self._clustersCatalog = self.generateDF(clusterCatPath)
    # Remove whitespaces included with some cluster names
    self._clustersCatalog['cluster'] = self._clustersCatalog['cluster'].str.strip()

    # Skip remaining set up if catalog already is up to date
    if not priorCatalog.empty:
        self.catalog = priorCatalog
        return

    # Build path string to the redshift catalog
    redshiftCatPath = self._path + 'DR2/CATS/Redshift_catalogue.fits'
    # Generate a DataFrame of the catalog data
    self._redshiftCatalog = self.generateDF(redshiftCatPath)
    # Build path string to the phot source catalogue
    photSourceCatPath = self._path + 'DR2/STELLPOPS_V2/photometry_stellpops.fits'
    # Generate a DataFrame of the catalog data
    self._photSourceCatalog = self.generateDF(photSourceCatPath)

    # Build path string to the spec source catalogue
    specSourceCatPath = self._path + 'DR2/STELLPOPS_V2/redshifts_stellpops.fits'
    # Generate a DataFrame of the catalog data
    self._specSourceCatalog = self.generateDF(specSourceCatPath)

    # Merge source catalogs into a combined catalog
    merge_col = ['SPECID']
    # This only ouputs columns with names different than those in the photometric source table.  
    # Make sure that SPECID is added back in as we will match on that field
    cols_to_use = self._specSourceCatalog.columns.difference(self._photSourceCatalog.columns).tolist() + merge_col
    self._combinedSourceCatalog = self.merge(self._photSourceCatalog, self._specSourceCatalog[cols_to_use], merge_col)

    # Build a DataFrame for each galfit and matched structural parameter cluster (11 total)
    # Then combine them into a single galfit catalog and a single matched catalog
    galfitCatPath = self._path + 'DR2/STRUCTURAL_PARA_v1.1_CATONLY/GALFIT_ORG_CATS/'
    matchedCatPath = self._path + 'DR2/STRUCTURAL_PARA_v1.1_CATONLY/STRUCTCAT_MATCHED/'
    for clusterName in self._structClusterNames:
        # Build filename strings
        galfitClusterFilename = 'gal_' + clusterName.lower() + '_orgcat.fits'
        matchedClusterFilename = 'structcat_photmatch_' + clusterName.lower() + '.dat'
        # Filename for SpARCSXXXX clusters in photmatched catalogs are spjXXXX
        if (clusterName[:6] == 'SpARCS'):
            galfitClusterFilename = 'gal_spj' + clusterName[-4:] + '_orgcat.fits'
            matchedClusterFilename = 'structcat_photmatch_spj' + clusterName[-4:] + '.dat'

        # Generate a DataFrame of the galfit cluster data
        galfitClusterDF = self.generateDF(galfitCatPath + galfitClusterFilename)
        # Combine it with the main galfit DataFrame
        self._galfitCatalog = self._galfitCatalog.append(galfitClusterDF)

        # Generate a DataFrame of the struct matched cluster data
        matchedClusterDF = self.generateDF(matchedCatPath + matchedClusterFilename)
        # Convert PHOTCATID to cPHOTID
        # Find a cPHOTID of the cluster in the photometric catalog 
        tempCPHOTID = self._combinedSourceCatalog[self._combinedSourceCatalog['Cluster'] == clusterName].iloc[0]['cPHOTID']
        # Extract the source ID and cluster ID from the temporary cPHOTID
        idPrefix = int(str(tempCPHOTID)[:3])*int(1e6)
        # Convert the structural catalog PHOTCATID into the photometric catalog cPHOTID
        matchedClusterDF.rename(columns = {'PHOTCATID':'cPHOTID'}, inplace = True)
        matchedClusterDF.loc[:,'cPHOTID'] += idPrefix
        # Combine it with the main struct matched DataFrame
        self._matchedCatalog = self._matchedCatalog.append(matchedClusterDF)

    # Merge combined source catalog with photomatched structural catalog by cPHOTID.
    self.catalog = self.merge(self._combinedSourceCatalog, self._matchedCatalog, 'cPHOTID')
    # readjust to preserve NaN values after merge
    self.catalog = self.catalog.replace(100000000000000000000, np.nan)
    self.catalog['NUVMINV'] = -2.5 * np.log10(self.catalog['NUV'] / self.catalog['V']) # added by me
    # Generate cluster-centric distance columns
    self.calcClusterCentricDist()
    # Generate flags for use in plotting
    self.generateFlags()
    # Establish membership
    self.setMembers(usePhotMembership)
    self.setNonMembers(usePhotMembership)
    # Set error values (necessary because the re_err values from Galfit are not adequate)
    self.setReErr()
    # Generate converted unit columns (kpc instead of arcsec) for re values.
    self.reConvert()
    # Generate fractional error columns
    self.catalog['re_frac_err'] = self.catalog['re_err_robust']/self.catalog['re']
    self.catalog['re_frac_err_converted'] = self.catalog['re_err_robust_converted']/self.catalog['re_converted']
    
    
# END INIT

# %% [markdown]
# Init function from lines 46 to 136 in GOGREEN.py

# %% [markdown]
# **Line 11**: Reads in Clusters.fits.\
# \
# **Line 23**: Reads in Redshift_catalogue.fits.\
# \
# **Lines 27 and 32**: Read in catalogues from the STELLPOPS_V2 folder. These catalogs, photometry_stellpops.fits and redshift_stellpops.fits, are created and edited through the proposal_plots_updated.ipynb notebook (see start of Tutorial.ipynb). These catalogs are created through merging the individual cluster data files, and are needed for the class to work. I obtained my version of these files from Gregory Rudnick and continued analysis after generating the files from the notebook failed. It is possible that the issue (described later) is created from these files, yet because the issue persists when referring line-by-line with the Photo.fits catalog, it is unlikely to be the sole cause. Just something to be mindful of as I haven't fully worked through the generation of these files. To work around not generating these, I added line 78, where the NUVMINV column is added, where it would be made by the same method generating the files. **IMPORTANT**\
# \
# **Lines 37-41**: Merge the last 2 catalogues - photometry_stellpops.fits and redshift_stellpops.fits - by the column `SPECID`, into one dataframe.\
# \
# **Lines 56-59**: Merge the galfit data for each cluster in `DR2/STRUCTURAL_PARA_v1.1_CATONLY/GALFIT_ORG_CATS/gal_{cluster}_orgcat.fits` into one master galfit catalog. This is not used anywhere else in GOGREEN.py so I assume it is used for debug and reference tasks.\
# \
# **Lines 61-72**: Do the same with the struct matched cluster data in `DR2/STRUCTURAL_PARA_v1.1_CATONLY/STRUCTCAT_MATCHED/structcat_photmatch_{cluster}.dat`, after converting the structural catalog PHOTCATID to cPHOTID used in the photometric catalog. These matched cluster data files are all added to the previous catalog made in lines 56-59. This is the final catalog with the data used in my analysis.

# %% [markdown]
# This final catalog has the columns of data:\
# \
# Cluster, cPHOTID, SPECID, ra, dec, zspec, Redshift_Quality, zphot, zphot_l68, zphot_u68, UMINV, VMINJ, Star, K_flag, totmask, Mstellar, u_tot, g_tot, r_tot, i_tot, z_tot, y_tot, V_tot, B_tot, J_tot, H_tot, K_tot, Ks_tot, IRAC1_tot, IRAC2_tot, IRAC3_tot, IRAC4_tot, IA484_tot, IA527_tot, IA624_tot, IA679_tot, IA738_tot, IA767_tot, IB427_tot, IB464_tot, IB505_tot, IB574_tot, IB709_tot, IB827_tot, fuv_tot, nuv_tot, mips24_tot, eu_tot, eg_tot, er_tot, ei_tot, ez_tot, ey_tot, eV_tot, eB_tot, eJ_tot, eH_tot, eK_tot, eKs_tot, eIRAC1_tot, eIRAC2_tot, eIRAC3_tot, eIRAC4_tot, eIA484_tot, eIA527_tot, eIA624_tot, eIA679_tot, eIA738_tot, eIA767_tot, eIB427_tot, eIB464_tot, eIB505_tot, eIB574_tot, eIB709_tot, eIB827_tot, efuv_tot, enuv_tot, emips24_tot, ltau, metal, lage, Av, lmass, lsfr, lssfr, la2t, chi2, FUV, NUV, U, V, cluster fullname, cluster_id, RA_Best, DEC_Best, RA_GMOS, DEC_GMOS, PA_deg, Redshift, vdisp, vdisp_err, gogreen_m1, gogreen_m2, gogreen_m3, gogreen_m4, gogreen_m5, gogreen_m6, gclass_m1, gclass_m2, gclass_m3, gclass_m4, gclass_m5, Kphot_cat, photoz_cat, stelmass_cat, IMAGE_U, IMAGE_B, IMAGE_G, IMAGE_V, IMAGE_R, IMAGE_I, IMAGE_Z, IMAGE_J, IMAGE_J1, IMAGE_Y, IMAGE_K, IMAGE_IRAC1, Preimage D4000, DEC(J2000), EWHdelta, EWOII, EWOII_model, EXTVER, F_OII, OBJClass, RA(J2000), Redshift_c, SFR_OII, SNR_8500_RMS, SNR_8500_VAR, Spec_Flag, delta_BIC, eD4000, eEWHdelta, eEWOII, eEWOII_model, eF_OII, eSFR_OII, member, member_Clean, member_EM, HSTFOV_flag, Fit_flag, mag, mag_err, re, re_err, n, n_err, q, q_err, pa, pa_err, dist, hst_id, chi2nu, S/N, NUVMINV, cluster_z, cluster_centric_distance_phot, cluster_centric_distance_spec, goodData, spectroscopic, photometric, passive, starForming, greenValley, blueQuiescent, postStarBurst, elliptical, spiral, member_adjusted, nonmember_adjusted, re_err_robust, re_converted, re_err_robust_converted, re_frac_err, re_frac_err_converted

# %% [markdown]
# ## Coordinate Mismatch Issue

# %% [markdown]
# As a part of verifying the results of my work, I began writing a code to view individual cutouts of galaxies alongside their fitted model and residuals. This was achieved by reading in the spj1051/OBJFITS_spj1051/galb1_1003_v_gf.fits type images. I fed in only the list of galaxies that met the criteria for my analysis, just to cut down the number of galaxies I had to visually inspect. The masking criteria is as follows:

# %%
'Star == 0',
'K_flag < 4',
'Mstellar > 10**9.8',
'(1 < zspec < 1.5) or ((((Redshift_Quality != 3) and (Redshift_Quality != 4)) or (SPECID < 0)) and (1 < zphot < 1.5))',
'cluster_id <= 12',
'totmask == 0',
'Fit_flag > 2',
'n < 6',
'HSTFOV_flag == 1',
're > 0'

# %% [markdown]
# I attached the filepath of which multi-extention fits file each galaxy corresponded to using the following block of code.

# %%
cluster_map = {
    1.0: 'spt0205',
    2.0: 'spt0546',
    3.0: 'spt2106',
    4.0: 'spj0035',
    5.0: 'spj0219',
    6.0: 'spj0335',
    8.0: 'spj1034',
    9.0: 'spj1051',
    10.0: 'spj1616',
    11.0: 'spj1634',
    12.0: 'spj1638',
}

# generating filename
def generate_fits_path(row):
    cid = row['cluster_id']
    hid = int(row['hst_id'])  # Convert HST_ID to integer for filename
    
    # Get the directory prefix from the map
    dir_name = cluster_map.get(cid)
    
    if dir_name:
        # gogreenfits/spj0335/OBJFITS_spj0335/galb1_1591_v_gf.fits
        return f"gogreenfits/{dir_name}/OBJFITS_{dir_name}/galb1_{hid}_v_gf.fits"
    return None

data['fits_filename'] = data.apply(generate_fits_path, axis=1) # apply filename

# %% [markdown]
# This code assumes that the filepath of each of these multi-extention fits files relied upon the HST ID. As I have limited knowledge of the workflow that generated these files and I can find little documentation, this is unknown. However, this worked well, opening nicely centered images of the galaxy in question.

# %% [markdown]
# ![Good.png](attachment:Good.png)

# %% [markdown]
# However, in certain clusters, specifically SPT0205, SPT0546, SpARCS0219, and SpARCS0035, when including a pointer at where my final merged catalog said the galaxy should be, there was a huge mismatch between the center of the fit image and the center of the galaxy, and the recorded coordinates.

# %% [markdown]
# ![Bad.png](attachment:Bad.png)

# %% [markdown]
# **Gal ID/CPHOTID:** 101001115\
# **Filepath:** gogreenfits/spt0205/OBJFITS_spt0205/galb1_1068_v_gf.fits\
# **RA, DEC:** 31.439262 -58.48716\
# **PIX X, PIX Y:** 701.6776516185089 198.967913237252

# %% [markdown]
# This, obviously, isn't good.

# %% [markdown]
# When we check this specific galaxy, 101001115, across multiple catalogs, we can compare sources of RA / DEC.

# %% [markdown]
# From DR2/STRUCTURAL_PARA_v1.1_CATONLY/STRUCTCAT_MATCHED/structcat_photmatch_spt0205.dat:\
# **PHOTCATID (last 4 in CPHOTID):** 1115\
# **n (Sersic index for making sure its the same galaxy):** 1.0454\
# **HST_ID:** 1068\
# \
# From DR2/STRUCTURAL_PARA_v1.1_CATONLY/GALFIT_ORG_CATS/gal_spt0205_orgcat.fits:\
# **GALA_ID (should equal HST_ID):** 1068\
# **RA_J2000**: 31.456926\
# **DEC_J2000**: -58.487735\
# **N_GALFIT_BAND**: 1.045374\
# \
# From DR2/CATS/Photo.fits:\
# **cPHOTID:** 101001115\
# **RA_J2000:** 31.439262\
# **RA_centre:** 31.451\
# **DEC_J2000**: -58.4803\
# **DEC_centre**: -58.48716

# %% [markdown]
# As you can see, the coordinates are off by a bit. This follows for nearly every galaxy in the 4 "BAD" clusters.\
# In SPT0205 3/46 of my galaxies have centers that are close enough to the center of the images.\
# (Galaxies 101000908, 101000976, and 101001009)\
# In SPT0546, SpARCS0219, and SpARCS0035, there are no such galaxies.

# %% [markdown]
# We can check if the measurements are affected by plotting the F160W mag from the structcat catalogs vs the magnitude of the average of the J and Ks flux from the Photo.fits file.

# %% [markdown]
# ### Ks band Mag

# %% [markdown]
# **Relation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Residuals**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### J band Mag

# %% [markdown]
# **Relation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Residuals**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Which shows that the measurements are in error for the 4 clusters that we suspected were bad.
